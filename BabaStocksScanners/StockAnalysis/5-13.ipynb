# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
from pandas_datareader import data as pdr

# %%
start = '2023-11-12'
end = '2024-02-22'

yf.pdr_override()
df = pdr.get_data_yahoo("TCS.NS", start=start, end=end)
df = df.reset_index()
df = df.drop(['Date', 'High', 'Low', 'Open', 'Volume', 'Adj Close'], axis = 1)
df
# Out:
# c:\Users\ishan\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
#           Close
# 0   3331.550049
# 1   3404.300049
# 2   3497.850098
# 3   3502.449951
# 4   3519.600098
# ..          ...
# 63  4103.200195
# 64  4128.299805
# 65  4103.799805
# 66  4030.649902
# 67  3991.500000
#
# [68 rows x 1 columns]

# %%
plt.figure(figsize=(20, 10))
plt.plot(df.Close, 'r', label = 'Close Price')
plt.xlabel("Time (in days)")
plt.ylabel("price")
plt.legend()
plt.show()

# %%
ma5 = df.Close.rolling(5).mean()
ma13 = df.Close.rolling(13).mean()

# %%
plt.figure(figsize=(20,10))
plt.plot(df.Close, 'y', label = 'Close')
plt.plot(ma5, 'r', label = '5 days Moving Average')
plt.plot(ma13, 'b', label = '13 days Moving Average')
plt.xlabel("Time")
plt.ylabel("Price")
plt.legend()
